# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyasri-1323/CP/blob/main/week1-2(D%26C).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def max_subarray(arr):
    if not arr:
        return 0 # Handle empty array case

    curr_sum = arr[0]
    max_sum = arr[0]

    for i in range(1, len(arr)): # Changed range to exclude len(arr)
        curr_sum = max(arr[i], curr_sum + arr[i])
        max_sum = max(max_sum, curr_sum)

    return max_sum



T = int(input())
for _ in range(T):
    n = int(input())
    arr = list(map(int, input().split()))
    print(max_subarray(arr))
# Out:
# 1
# 9
# -2 1 -3 4 -1 2 1 -5 4
# 6
